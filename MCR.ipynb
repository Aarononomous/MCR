# %%
# magic
# %matplotlib inline

# imports
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# from IPython.display import SVG, display # svg images
import graphviz as gv
import random as rand
from math import *

# my libraries
from MCR import *

# make figures large enough
from pylab import rcParams
rcParams['figure.figsize'] = (10, 10)

# %%
# Create an empty square
square = MCR()

# %%
# Add a couple of shapes to the square
shape1 = Polygon([(0.2,0.2), (0.2, 0.7), (0.7,0.7), (0.7,0.2)])
shape2 = Polygon([(0.5,0.15), (1.0,0.15), (.75, .87)])

square.add_obstacle(shape1)
square.add_obstacle(shape2)

# Add a start and goal
square.start = (0.05, 0.05)
square.goal  = (0.95, 0.95)

# %%
# Display the MCR
square.show_obstacles()
# Out:
# 0: 0.2020833333333333
# 0, 1: 0.04791666666666663
# 1: 0.13208333333333336

# %%
square.overlapped_obstacles[2]

# %%
svg_square = MCR(svg='path/to/missing.svg')
# Out:
# File path/to/missing.svg not found
# Couldn't load all shapes

# %%
straws = MCR(svg='straws.svg')

# %%
straws.show_obstacles()
# Out:
# 0, 10: 0.0050821283559873125
# 1, 10: 0.005082128355987313
# 2, 10: 0.005082128355987311
# 3, 10: 0.005082128355987311
# 4, 10: 0.005082128355987311
# 5, 10: 0.005082128355987311
# 6, 10: 0.005082128355987311
# 7, 10: 0.005082128355987303
# 8, 10: 0.005082128355987303
# 9, 10: 0.005081774027858186
# 10: 0.0022740779327007285
# 10: 0.0022744322608298524
# 10: 0.0022740779327007276
# 10: 0.0022744322608298567
# 10: 0.0022740779327007276
# 10: 0.0022740779327007276
# 10: 0.0022744322608298606
# 10: 0.0022740779327007354
# 10: 0.0022744322608298606
# 0: 0.002274077932700728
# 0, 11: 0.0050821283559873125
# 1: 0.0022740779327007285
# 1, 11: 0.005082128355987313
# 2: 0.0022740779327007276
# 2, 11: 0.005082128355987311
# 3: 0.0022740779327007276
# 3, 11: 0.005082128355987311
# 4: 0.0022740779327007276
# 4, 11: 0.005082128355987311
# 5: 0.0022740779327007276
# 5, 11: 0.005082128355987311
# 6: 0.0022740779327007276
# 6, 11: 0.005082128355987311
# 7: 0.002274077932700724
# 7, 11: 0.005082128355987303
# 8: 0.002274077932700724
# 8, 11: 0.005082128355987303
# 9, 11: 0.005081774027858186
# 11: 0.0022740779327007285
# 11: 0.0022744322608298524
# 11: 0.0022740779327007276
# 11: 0.0022744322608298567
# 11: 0.0022740779327007276
# 11: 0.0022740779327007276
# 11: 0.0022744322608298606
# 11: 0.0022740779327007354
# 11: 0.0022744322608298606
# 0: 0.002274432260829853
# 0, 12: 0.0050821283559873125
# 1: 0.0022744322608298532
# 1, 12: 0.005082128355987313
# 2: 0.0022744322608298524
# 2, 12: 0.005082128355987311
# 3: 0.0022744322608298524
# 3, 12: 0.005082128355987311
# 4: 0.0022744322608298524
# 4, 12: 0.005082128355987311
# 5: 0.0022744322608298524
# 5, 12: 0.005082128355987311
# 6: 0.0022744322608298524
# 6, 12: 0.005082128355987311
# 7: 0.002274432260829849
# 7, 12: 0.005082128355987303
# 8: 0.002274432260829849
# 8, 12: 0.005082128355987303
# 9, 12: 0.005081774027858186
# 12: 0.0022740779327007285
# 12: 0.0022744322608298524
# 12: 0.0022740779327007276
# 12: 0.0022744322608298567
# 12: 0.0022740779327007276
# 12: 0.0022740779327007276
# 12: 0.0022744322608298606
# 12: 0.0022740779327007354
# 12: 0.0022744322608298606
# 0: 0.002274077932700728
# 0, 13: 0.0050821283559873125
# 1: 0.0022740779327007285
# 1, 13: 0.005082128355987313
# 2: 0.0022740779327007276
# 2, 13: 0.005082128355987311
# 3: 0.0022740779327007276
# 3, 13: 0.005082128355987311
# 4: 0.0022740779327007276
# 4, 13: 0.005082128355987311
# 5: 0.0022740779327007276
# 5, 13: 0.005082128355987311
# 6: 0.0022740779327007276
# 6, 13: 0.005082128355987311
# 7: 0.002274077932700724
# 7, 13: 0.005082128355987303
# 8: 0.002274077932700724
# 8, 13: 0.005082128355987303
# 9, 13: 0.005081774027858186
# 13: 0.0022740779327007285
# 13: 0.0022744322608298524
# 13: 0.0022740779327007276
# 13: 0.0022744322608298567
# 13: 0.0022740779327007276
# 13: 0.0022740779327007276
# 13: 0.0022744322608298606
# 13: 0.0022740779327007354
# 13: 0.0022744322608298606
# 0: 0.002274432260829861
# 0, 14: 0.0050821283559873125
# 1: 0.0022744322608298615
# 1, 14: 0.005082128355987313
# 2: 0.0022744322608298606
# 2, 14: 0.005082128355987311
# 3: 0.0022744322608298606
# 3, 14: 0.005082128355987311
# 4: 0.0022744322608298606
# 4, 14: 0.005082128355987311
# 5: 0.0022744322608298606
# 5, 14: 0.005082128355987311
# 6: 0.0022744322608298606
# 6, 14: 0.005082128355987311
# 7: 0.002274432260829857
# 7, 14: 0.005082128355987303
# 8: 0.002274432260829857
# 8, 14: 0.005082128355987303
# 9, 14: 0.005081774027858186
# 14: 0.0022740779327007285
# 14: 0.0022744322608298524
# 14: 0.0022740779327007276
# 14: 0.0022744322608298567
# 14: 0.0022740779327007276
# 14: 0.0022740779327007276
# 14: 0.0022744322608298606
# 14: 0.0022740779327007354
# 14: 0.0022744322608298606
# 0: 0.002274077932700728
# 0, 15: 0.0050821283559873125
# 1: 0.0022740779327007285
# 1, 15: 0.005082128355987313
# 2: 0.0022740779327007276
# 2, 15: 0.005082128355987311
# 3: 0.0022740779327007276
# 3, 15: 0.005082128355987311
# 4: 0.0022740779327007276
# 4, 15: 0.005082128355987311
# 5: 0.0022740779327007276
# 5, 15: 0.005082128355987311
# 6: 0.0022740779327007276
# 6, 15: 0.005082128355987311
# 7: 0.002274077932700724
# 7, 15: 0.005082128355987303
# 8: 0.002274077932700724
# 8, 15: 0.005082128355987303
# 9, 15: 0.005081774027858186
# 15: 0.0022740779327007285
# 15: 0.0022744322608298524
# 15: 0.0022740779327007276
# 15: 0.0022744322608298567
# 15: 0.0022740779327007276
# 15: 0.0022740779327007276
# 15: 0.0022744322608298606
# 15: 0.0022740779327007354
# 15: 0.0022744322608298606
# 0: 0.002274077932700728
# 0, 16: 0.0050821283559873125
# 1: 0.0022740779327007285
# 1, 16: 0.005082128355987313
# 2: 0.0022740779327007276
# 2, 16: 0.005082128355987311
# 3: 0.0022740779327007276
# 3, 16: 0.005082128355987311
# 4: 0.0022740779327007276
# 4, 16: 0.005082128355987311
# 5: 0.0022740779327007276
# 5, 16: 0.005082128355987311
# 6: 0.0022740779327007276
# 6, 16: 0.005082128355987311
# 7: 0.002274077932700724
# 7, 16: 0.005082128355987303
# 8: 0.002274077932700724
# 8, 16: 0.005082128355987303
# 9, 16: 0.005081774027858186
# 16: 0.0022740779327007285
# 16: 0.0022744322608298524
# 16: 0.0022740779327007276
# 16: 0.0022744322608298567
# 16: 0.0022740779327007276
# 16: 0.0022740779327007276
# 16: 0.0022744322608298606
# 16: 0.0022740779327007354
# 16: 0.0022744322608298606
# 0: 0.002274432260829861
# 0, 17: 0.005082128355987304
# 1: 0.0022744322608298615
# 1, 17: 0.005082128355987306
# 2: 0.0022744322608298606
# 2, 17: 0.005082128355987303
# 3: 0.0022744322608298606
# 3, 17: 0.005082128355987303
# 4: 0.0022744322608298606
# 4, 17: 0.005082128355987303
# 5: 0.0022744322608298606
# 5, 17: 0.005082128355987303
# 6: 0.0022744322608298606
# 6, 17: 0.005082128355987303
# 7: 0.002274432260829857
# 7, 17: 0.005082128355987295
# 8: 0.002274432260829857
# 8, 17: 0.005082128355987295
# 9, 17: 0.005081774027858178
# 17: 0.002274077932700725
# 17: 0.002274432260829849
# 17: 0.002274077932700724
# 17: 0.002274432260829853
# 17: 0.002274077932700724
# 17: 0.002274077932700724
# 17: 0.002274432260829857
# 17: 0.002274077932700732
# 17: 0.002274432260829857
# 0: 0.002274077932700736
# 0, 18: 0.005082128355987304
# 1: 0.0022740779327007363
# 1, 18: 0.005082128355987306
# 2: 0.0022740779327007354
# 2, 18: 0.005082128355987303
# 3: 0.0022740779327007354
# 3, 18: 0.005082128355987303
# 4: 0.0022740779327007354
# 4, 18: 0.005082128355987303
# 5: 0.0022740779327007354
# 5, 18: 0.005082128355987303
# 6: 0.0022740779327007354
# 6, 18: 0.005082128355987303
# 7: 0.002274077932700732
# 7, 18: 0.005082128355987295
# 8: 0.002274077932700732
# 8, 18: 0.005082128355987295
# 9, 18: 0.005081774027858178
# 18: 0.002274077932700725
# 18: 0.002274432260829849
# 18: 0.002274077932700724
# 18: 0.002274432260829853
# 18: 0.002274077932700724
# 18: 0.002274077932700724
# 18: 0.002274432260829857
# 18: 0.002274077932700732
# 18: 0.002274432260829857
# 0: 0.002274432260829861
# 0, 19: 0.005081774027858187
# 1: 0.0022744322608298615
# 1, 19: 0.005081774027858189
# 2: 0.0022744322608298606
# 2, 19: 0.005081774027858186
# 3: 0.0022744322608298606
# 3, 19: 0.005081774027858186
# 4: 0.0022744322608298606
# 4, 19: 0.005081774027858186
# 5: 0.0022744322608298606
# 5, 19: 0.005081774027858186
# 6: 0.0022744322608298606
# 6, 19: 0.005081774027858186
# 7: 0.002274432260829857
# 7, 19: 0.005081774027858178
# 8: 0.002274432260829857
# 8, 19: 0.005081774027858178
# 9: 0.020471661963410426
# 9, 19: 0.005081419724432968
# 19: 0.020471661963410423

# %%
nine = list(filter(lambda x:x.label == '9', straws.overlapped_obstacles))[0]

# %%
nine

# %%
straws2 = MCR(svg='straws2.svg')

# %%
nineteen = list(filter(lambda x:x.label == '19', straws2.overlapped_obstacles))[0]

# %%
nineteen

# %%
straws.show_bare_obstacles()
# Out:
# 0: 0.07128904793856707
# 1: 0.07128904793856708
# 2: 0.07128904793856705
# 3: 0.07128904793856705
# 4: 0.07128904793856705
# 5: 0.07128904793856705
# 6: 0.07128904793856705
# 7: 0.07128904793856694
# 8: 0.07128904793856694
# 9: 0.07128904793856705
# 10: 0.07128904793856705
# 11: 0.07128904793856705
# 12: 0.07128904793856705
# 13: 0.07128904793856705
# 14: 0.07128904793856705
# 15: 0.07128904793856705
# 16: 0.07128904793856705
# 17: 0.07128904793856694
# 18: 0.07128904793856694
# 19: 0.07128904793856705

# %%
straws.obstacles
# Out:
# [<shapely.geometry.polygon.Polygon at 0x110ad6cc0>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6d30>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6dd8>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6cf8>,
#  <shapely.geometry.polygon.Polygon at 0x110ad69e8>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6b38>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6c18>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6940>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6978>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6a90>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6358>,
#  <shapely.geometry.polygon.Polygon at 0x110ad63c8>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6470>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6390>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6198>,
#  <shapely.geometry.polygon.Polygon at 0x110ad61d0>,
#  <shapely.geometry.polygon.Polygon at 0x110ad62b0>,
#  <shapely.geometry.polygon.Polygon at 0x110ad60b8>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6080>,
#  <shapely.geometry.polygon.Polygon at 0x110ad6e10>]

# %%
shapes = MCR(svg='shapes.svg')

# %%
shapes.show_obstacles()
# Out:
# 0: 0.0031545609509045693
# 2: 0.044623147230683266
# 2: 0.0004208729841569938
# 1, 2: 0.015268563439411477
# 1, 2, 3: 0.012938228688521207
# 4: 0.0003476748412007636
# 0, 2: 0.07974910721190678
# 0, 2, 5: 0.007601989029332084
# 0: 0.004718366326603338
# 0: 0.007827908951806807
# 0, 5: 0.008431531552829316
# 0: 0.1389394498951983
# 0, 5: 0.04464565920335675
# 0, 4: 0.011939074934100395
# 0, 4, 5: 0.047585533225923245
# 4: 0.01493438270749846
# 4, 5: 0.012527526779871491
# 5: 0.06632743482450873
# 1: 0.1122822495391762
# 1, 6: 0.0029223034608408926
# 1, 6: 0.002871259823734843
# 1, 6: 0.0015835290950059343
# 1, 3: 0.08701507600119211
# 1, 3, 6: 0.04440926902924555
# 6: 4.336808689942018e-19

# %%
shapes.obstacles

# %%
for s in shapes.obstacles:
    print(s.exterior)

# %%
f = random_mcr(20)
f.show_bare_obstacles()

# %%
r = f.obstacles[15] - f.obstacles[7]

# %%
type(r)

# %%
for p in r:
    print(p)

# %%
rotations = MCR(svg='rotation.svg')
rotations.show_obstacles()

# %%
MCR
